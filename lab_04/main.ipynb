# %%
from data_funcs import *
from least_squares_1D import least_squares_method_1D, grafic_aprox_function_1D
from least_squares_2D import least_squares_method_2D, grafic_aprox_function_2D
from ODE import ODE
from matplotlib import pyplot as plt
import copy

# %%
def f_1d(x):
    return x**2

# %%
def f_2d(x, y):
    return x**3 + np.cos(4+y-2)*5

# %%
# table_1D = generate_data_1D(f_1d, -5, 5, 10)
table_1D = generate_from_file_1D("data/data_1D/data_1.txt")
table_1D_w1 = copy.deepcopy(table_1D)
set_all_weight(table_1D_w1)

# %%
print_data(table_1D)
# Out:
# 0) 0.0 1.0 0 100.0
# 1) 2.5 -0.048 0 7.0
# 2) 5.0 -0.178 0 5.0
# 3) 7.5 0.266 0 0.1
# 4) 10.0 -0.246 0 100.0

# %%
# table_2D = generate_data_2D(f_2d, -5, 5, -5, 5, 5, 4)
table_2D = generate_from_file_2D("data/data_2D/data_3.txt")
table_2D_w1 = copy.deepcopy(table_2D)
set_all_weight(table_2D_w1)

# %%
print_data(table_2D)
# Out:
# 0) -2.0 -1.0 -10.0 2.0
# 1) -2.0 0.0 -12.0 8.0
# 2) -2.0 1.0 -12.0 7.0
# 3) -2.0 2.0 -10.0 6.0
# 4) -1.0 -1.0 -3.0 0.0
# 5) -1.0 0.0 -4.0 3.0
# 6) -1.0 1.0 -3.0 6.0
# 7) -1.0 2.0 0.0 1.0
# 8) 0.0 -1.0 -0.0 6.0
# 9) 0.0 0.0 0.0 9.0
# 10) 0.0 1.0 2.0 3.0
# 11) 0.0 2.0 6.0 6.0
# 12) 1.0 -1.0 -1.0 3.0
# 13) 1.0 0.0 0.0 1.0
# 14) 1.0 1.0 3.0 1.0
# 15) 1.0 2.0 8.0 0.0
# 16) 2.0 -1.0 -6.0 0.0
# 17) 2.0 0.0 -4.0 4.0
# 18) 2.0 1.0 0.0 5.0
# 19) 2.0 2.0 6.0 3.0

# %%
grafic_aprox_function_1D(least_squares_method_1D(
    table_1D, 1), table_1D, color='green', label="n = 1")
grafic_aprox_function_1D(least_squares_method_1D(
    table_1D, 2, print_mode=True), table_1D, color='blue', label="n = 2")
# Out:
# Матрица СЛАУ:
#           212.1         1043.25         10174.4         74.2006
#         1043.25         10174.4          100777         -251.09
#         10174.4          100777     1.00371e+06        -2482.85
# Результаты подсчетов коэффициент:
# a0 =   0.995109
# a1 =  -0.417562
# a2 =  0.0293639

# %%
axes = grafic_aprox_function_2D(
    least_squares_method_2D(table_2D, 1), table_2D, color='green')
grafic_aprox_function_2D(least_squares_method_2D(
    table_2D, 2, print_mode=True), table_2D, color='blue', axes=axes)
# Out:
# Матрица СЛАУ:
#              74              43              97             -27             -22             155            -246
#              43              97             139             -22             -38             118             -82
#              97             139             289             -38             -64             214            -140
#             -27             -22             -38             155             118             -93             554
#             -22             -38             -64             118             214             -58             464
#             155             118             214             -93             -58             575           -1062
# Результаты подсчетов коэффициент:
# a0 = -1.92039e-16
# a1 =          1
# a2 =          1
# a3 =          2
# a4 =          1
# a5 =         -2
# <Axes3D: xlabel='OX', ylabel='OY', zlabel='OZ'>

# %%
grafic_aprox_function_1D(least_squares_method_1D(table_1D_w1, 1), table_1D_w1, color='green', label="n = 1 w = 1")
grafic_aprox_function_1D(least_squares_method_1D(table_1D, 1), table_1D, color='blue', label="n = 1")

# %%
x, y, y_2, y_3 = ODE()

plt.grid(True)

plt.plot(x, y_2, color="blue", label="m = 2")
plt.plot(x, y_3, color="red", label="m = 3")
plt.plot(x, y, color="green", label="Init func")

plt.legend()
# Out:
# [ 0.00563435 -0.31208419]
# [-0.31435849 -0.60890724  0.17276528]
